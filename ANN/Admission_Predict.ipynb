# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv("Admission_Predict.csv")

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.shape
# Out:
# (400, 9)

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.3 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=["Serial No."],inplace=True)

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]

# %%
X
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 93         301           97                  2  3.0   3.0  7.88         1
# 23         334          119                  5  5.0   4.5  9.70         1
# 299        305          112                  3  3.0   3.5  8.65         0
# 13         307          109                  3  4.0   3.0  8.00         1
# 90         318          106                  2  4.0   4.0  7.92         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 255        307          110                  4  4.0   4.5  8.37         0
# 72         321          111                  5  5.0   5.0  9.45         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 235        326          111                  5  4.5   4.0  9.23         1
# 37         300          105                  1  1.0   2.0  7.80         0
#
# [320 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
X_train_scaled
# Out:
# array([[0.22      , 0.17857143, 0.25      , ..., 0.42857143, 0.25      ,
#         1.        ],
#        [0.88      , 0.96428571, 1.        , ..., 0.85714286, 0.91911765,
#         1.        ],
#        [0.3       , 0.71428571, 0.5       , ..., 0.57142857, 0.53308824,
#         0.        ],
#        ...,
#        [0.7       , 0.53571429, 0.5       , ..., 0.57142857, 0.70220588,
#         1.        ],
#        [0.72      , 0.67857143, 1.        , ..., 0.71428571, 0.74632353,
#         1.        ],
#        [0.2       , 0.46428571, 0.        , ..., 0.14285714, 0.22058824,
#         0.        ]])

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(7,activation="relu",input_dim=7))
model.add(Dense(7,activation="relu"))
model.add(Dense(1,activation="linear"))
# Out:
# C:\Users\Abdul Tahir\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 7)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │            14 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │             8 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 272 (1.07 KB)
#  Trainable params: 142 (568.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 130 (524.00 B)

# %%
model.compile(loss="mean_squared_error",optimizer="Adam")

# %%
history = model.fit(X_train_scaled,y_train,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.5601 - val_loss: 0.5826
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5190 - val_loss: 0.5467
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4927 - val_loss: 0.5253
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4706 - val_loss: 0.4999
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4459 - val_loss: 0.4728
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4208 - val_loss: 0.4478
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3970 - val_loss: 0.4218
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3720 - val_loss: 0.3947
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3462 - val_loss: 0.3670
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.3200 - val_loss: 0.3381
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.2927 - val_loss: 0.3084
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2647 - val_loss: 0.2775
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2356 - val_loss: 0.2454
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2058 - val_loss: 0.2118
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1741 - val_loss: 0.1767
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.1418 - val_loss: 0.1400
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.1085 - val_loss: 0.1030
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0764 - val_loss: 0.0677
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0472 - val_loss: 0.0379
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0252 - val_loss: 0.0170
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0122 - val_loss: 0.0065
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0071 - val_loss: 0.0037
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0066 - val_loss: 0.0035
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0069 - val_loss: 0.0035
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0067 - val_loss: 0.0035
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0065 - val_loss: 0.0036
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0064 - val_loss: 0.0037
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0064 - val_loss: 0.0037
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0063 - val_loss: 0.0037
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0063 - val_loss: 0.0036
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0062 - val_loss: 0.0036
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0062 - val_loss: 0.0036
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0062 - val_loss: 0.0035
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0061 - val_loss: 0.0035
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0061 - val_loss: 0.0036
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0061 - val_loss: 0.0036
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0060 - val_loss: 0.0036
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0060 - val_loss: 0.0035
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0060 - val_loss: 0.0035
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0060 - val_loss: 0.0035
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0059 - val_loss: 0.0035
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0059 - val_loss: 0.0035
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0059 - val_loss: 0.0035
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0058 - val_loss: 0.0035
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0058 - val_loss: 0.0035
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0058 - val_loss: 0.0035
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0058 - val_loss: 0.0035
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0057 - val_loss: 0.0034
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0057 - val_loss: 0.0034
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0056 - val_loss: 0.0035
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0056 - val_loss: 0.0035
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0055 - val_loss: 0.0035
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0055 - val_loss: 0.0035
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0054 - val_loss: 0.0035
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0052 - val_loss: 0.0035
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0052 - val_loss: 0.0035
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0050 - val_loss: 0.0034
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0050 - val_loss: 0.0034
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0050 - val_loss: 0.0034
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0050 - val_loss: 0.0034
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0050 - val_loss: 0.0034
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0049 - val_loss: 0.0035
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0049 - val_loss: 0.0034
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0049 - val_loss: 0.0035
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0049 - val_loss: 0.0034
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0049 - val_loss: 0.0035

# %%
y_pred = model.predict(X_test_scaled)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7465121630923248

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
