# %%
import numpy as np 
import pandas as pd

# %%
df = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]],columns=['cgpa','profile_score','lpa'])

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
def initialize_parameters(layer_dims):
    np.random.seed(3)
    parameters = {}
    L = len(layer_dims)


    for l in range(1,L):
        parameters['w' + str(l)] = np.ones((layer_dims[l-1],layer_dims[l]))*0.1
        parameters['b' + str(l)] = np.zeros((layer_dims[l],1))
        
    return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'w1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'w2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev,w,b):
    Z = np.dot(W.T,A_prev) + b

    return Z

# %%
def L_layer_forward(X, parameters):
    A = X
    L = len(parameters) // 2   # number of layers in the network

    for l in range(1, L + 1):
        A_prev = A
        W = parameters['W' + str(l)]
        b = parameters['b' + str(l)]

        print("A" + str(l-1) + ": ", A_prev)
        print("W" + str(l) + ": ", W)
        print("b" + str(l) + ": ", b)
        print("- -" * 20)

        # Forward step
        A = linear_forward(A_prev, W, b)

        print("A" + str(l) + ": ", A)
        print("**" * 20)

    return A, A_prev   # <-- moved outside the loop

# %%
X = df[['cgpa','profile_score']].values[0].reshape(2,1)  # Shape (no. of feature, no of training example)
y = df[['lpa']].values[0][0]

#parameter initialization
parameters = initialize_parameters([2,2,1])
L_layer_foward(X,parameters)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 6
#       4 #parameter initialization
#       5 parameters = initialize_parameters([2,2,1])
# ----> 6 L_layer_foward(X,parameters)
#
# Cell In[18], line 8, in L_layer_foward(X, parameters)
#       6 for l in range(1,L+1):
#       7     A_prev = A
# ----> 8     W1 = parameters['W' + str(l)]
#       9     b1 = parameters['b' + str(l)]
#      10     print("A"+str(l-1)+": ",A_prev)
#
# KeyError: 'W1'

# %%
import numpy as np

def initialize_parameters(layers_dims):
    np.random.seed(1)
    parameters = {}
    L = len(layers_dims)

    for l in range(1, L):
        parameters['W' + str(l)] = np.random.randn(layers_dims[l], layers_dims[l-1]) * 0.01
        parameters['b' + str(l)] = np.zeros((layers_dims[l], 1))
    return parameters

def linear_forward(A_prev, W, b):
    Z = np.dot(W, A_prev) + b
    A = np.maximum(0, Z)  # ReLU activation
    return A

def L_layer_forward(X, parameters):
    A = X
    L = len(parameters) // 2
    for l in range(1, L + 1):
        A_prev = A
        W = parameters['W' + str(l)]
        b = parameters['b' + str(l)]
        print(f"\nLayer {l}")
        print("A_prev:", A_prev)
        print("W:", W)
        print("b:", b)
        print("-" * 40)
        A = linear_forward(A_prev, W, b)
        print("A:", A)
    return A

# Example data
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1)
y = df[['lpa']].values[0][0]

parameters = initialize_parameters([2, 2, 1])  # <-- ensures W1, b1, W2, b2 exist
output = L_layer_forward(X, parameters)
print("\nFinal Output (Prediction):", output)
# Out:
# Layer 1
# A_prev: [[8]
#  [8]]
# W: [[ 0.01624345 -0.00611756]
#  [-0.00528172 -0.01072969]]
# b: [[0.]
#  [0.]]
# ----------------------------------------
# A: [[0.08100712]
#  [0.        ]]
#
# Layer 2
# A_prev: [[0.08100712]
#  [0.        ]]
# W: [[ 0.00865408 -0.02301539]]
# b: [[0.]]
# ----------------------------------------
# A: [[0.00070104]]
#
# Final Output (Prediction): [[0.00070104]]
